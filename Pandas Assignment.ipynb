# %%
##1. Import pandas under the alias pd.

import pandas as pd
import numpy as np

# %%
##2. Print the version of pandas that has been imported.

print(pd.__version__)
# Out:
# 1.5.3

# %%
##3. Try checking for the help of any of the function in pandas.

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']


##4. Create a DataFrame df from this dictionary data which has the index labels.

# %%
df=pd.DataFrame(data,index=labels)

# %%
df.head(10)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
##5. Display a summary of the basic information about this DataFrame and its data (hint: there is a single method that can be called on the DataFrame).
df.describe(include="all")
# Out:
#        animal       age     visits priority
# count      10  8.000000  10.000000       10
# unique      3       NaN        NaN        2
# top       cat       NaN        NaN       no
# freq        4       NaN        NaN        6
# mean      NaN  3.437500   1.900000      NaN
# std       NaN  2.007797   0.875595      NaN
# min       NaN  0.500000   1.000000      NaN
# 25%       NaN  2.375000   1.000000      NaN
# 50%       NaN  3.000000   2.000000      NaN
# 75%       NaN  4.625000   2.750000      NaN
# max       NaN  7.000000   3.000000      NaN

# %%
##6. Return the first 3 rows of the DataFrame df.

df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
##7. Select just the 'animal' and 'age' columns from the DataFrame df.

df[['animal','age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
##8. Select the data in rows [3, 4, 8] and in columns ['animal', 'age'].
df.loc[['c','d','h'],['animal','age']]
# Out:
#   animal  age
# c  snake  0.5
# d    dog  NaN
# h    cat  NaN

# %%
##9. Select only the rows where the number of visits is greater than 3.

df[df.visits>3]
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %%
##10. Check for missing values in the data.

df.isnull().sum()
# Out:
# animal      0
# age         2
# visits      0
# priority    0
# dtype: int64

# %%
##11. Select the rows where the animal is a cat and the age is less than 3.

df[df.visits<3]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# c  snake  0.5       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
##12. Select the rows the age is between 2 and 4 (inclusive).

df.loc[['a','b','f','j'],['age']]
# Out:
#    age
# a  2.5
# b  3.0
# f  2.0
# j  3.0

# %%
##13. Change the age in row 'f' to 1.5.

df['age'].replace([2.0], 1.5)
# Out:
# a    2.5
# b    3.0
# c    0.5
# d    NaN
# e    5.0
# f    1.5
# g    4.5
# h    NaN
# i    7.0
# j    3.0
# Name: age, dtype: float64

# %%
##14. Calculate the sum of all visits in df (i.e. find the total number of visits).

df.sum()
# Out:
# animal      catcatsnakedogdogcatsnakecatdogdog
# age                                       27.0
# visits                                      19
# priority              yesyesnoyesnononoyesnono
# dtype: object

# %%
##15. Calculate the mean age for each different animal in df. Explore the groupby function.

df1 = df.groupby(['age']).mean()
df1
# Out:
# <ipython-input-41-4831d9f7d4ce>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = df.groupby(['age']).mean()
#      visits  visit
# age
# 0.5     2.0    NaN
# 1.5     3.0    3.0
# 2.5     1.0    NaN
# 3.0     2.0    NaN
# 4.5     1.0    NaN
# 5.0     2.0    NaN
# 7.0     2.0    NaN

# %%
##16. Append a new row 'k' to df with your choice of values for each column. Then delete that row to return the original DataFrame.

df2 = {'animal': 'turtle', 'age': 1.9, 'visits': 3,'priority':'yes'}
df = df.append(df2, ignore_index = True)
display(df)
# Out:
# <ipython-input-64-47db7aa66cd0>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2, ignore_index = True)
#     animal  age  visits priority  visit  labels
# 0      cat  2.5     1.0     True    NaN     NaN
# 1      cat  3.0     3.0     True    NaN     NaN
# 2   python  0.5     2.0    False    NaN     NaN
# 3      dog  NaN     3.0     True    NaN     NaN
# 4      dog  5.0     2.0    False    NaN     NaN
# 5      cat  1.5     3.0    False    NaN     NaN
# 6   python  4.5     1.0    False    NaN     NaN
# 7      cat  NaN     1.0     True    NaN     NaN
# 8      dog  7.0     2.0    False    NaN     NaN
# 9      dog  3.0     1.0    False    NaN     NaN
# 10  turtle  1.5     NaN     True    3.0     NaN
# 11  turtle  1.9     3.0      yes    NaN     NaN

# %%
##17. Count the number of each type of animal in df.

df1 = df.groupby(['animal']).animal.count()
display(df1)
# Out:
# animal
# cat       4
# dog       4
# snake     2
# turtle    1
# Name: animal, dtype: int64

# %%
##18. Sort df first by the values in the 'age' in decending order, then by the value in the 'visit' column in ascending order (so row i should be first, and row d should be last).

df.sort_values(by=['age', 'visits'],
        ascending=[False, True]).head(10)
# Out:
#     animal  age  visits priority  visit labels
# 8      dog  7.0     2.0       no    NaN    NaN
# 4      dog  5.0     2.0       no    NaN    NaN
# 6    snake  4.5     1.0       no    NaN    NaN
# 9      dog  3.0     1.0       no    NaN    NaN
# 1      cat  3.0     3.0      yes    NaN    NaN
# 0      cat  2.5     1.0      yes    NaN    NaN
# 5      cat  1.5     3.0       no    NaN    NaN
# 10  turtle  1.5     NaN      yes    3.0    NaN
# 2    snake  0.5     2.0       no    NaN    NaN
# 7      cat  NaN     1.0      yes    NaN    NaN

# %%
##19. The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be True and 'no' should be False.

df.priority = df.priority.replace({'yes': True, 'no': False})
df.priority
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# Name: priority, dtype: bool

# %%
df.head(10)
# Out:
#   animal  age  visits  priority  visit labels
# 0    cat  2.5     1.0      True    NaN    NaN
# 1    cat  3.0     3.0      True    NaN    NaN
# 2  snake  0.5     2.0     False    NaN    NaN
# 3    dog  NaN     3.0      True    NaN    NaN
# 4    dog  5.0     2.0     False    NaN    NaN
# 5    cat  1.5     3.0     False    NaN    NaN
# 6  snake  4.5     1.0     False    NaN    NaN
# 7    cat  NaN     1.0      True    NaN    NaN
# 8    dog  7.0     2.0     False    NaN    NaN
# 9    dog  3.0     1.0     False    NaN    NaN

# %%
##20. In the 'animal' column, change the 'snake' entries to 'python'.

df= df.replace({'snake':'python'})
display(df)
# Out:
#     animal  age  visits  priority  visit  labels
# 0      cat  2.5     1.0      True    NaN     NaN
# 1      cat  3.0     3.0      True    NaN     NaN
# 2   python  0.5     2.0     False    NaN     NaN
# 3      dog  NaN     3.0      True    NaN     NaN
# 4      dog  5.0     2.0     False    NaN     NaN
# 5      cat  1.5     3.0     False    NaN     NaN
# 6   python  4.5     1.0     False    NaN     NaN
# 7      cat  NaN     1.0      True    NaN     NaN
# 8      dog  7.0     2.0     False    NaN     NaN
# 9      dog  3.0     1.0     False    NaN     NaN
# 10  turtle  1.5     NaN      True    3.0     NaN
