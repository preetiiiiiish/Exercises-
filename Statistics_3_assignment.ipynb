# %% [markdown]
# **1.Import necessary packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **2.Load the file**

# %%
df=pd.read_csv("https://raw.githubusercontent.com/preetiiiiiish/Datasets/main/Inc_Exp_Data%20(1)%20dataset.csv")
df
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000              8000                  3             2000
# 1              6000              7000                  2             3000
# 2             10000              4500                  2                0
# 3             10000              2000                  1                0
# 4             12500             12000                  2             3000
# 5             14000              8000                  2                0
# 6             15000             16000                  3            35000
# 7             18000             20000                  5             8000
# 8             19000              9000                  2                0
# 9             20000              9000                  4                0
# 10            20000             18000                  4             8000
# 11            22000             25000                  6            12000
# ...

# %% [markdown]
# **3.Analyze the data**

# %%
df.describe(include="all")
# Out:
#         Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count         50.000000         50.000000          50.000000        50.000000
# unique              NaN               NaN                NaN              NaN
# top                 NaN               NaN                NaN              NaN
# freq                NaN               NaN                NaN              NaN
# mean       41558.000000      18818.000000           4.060000      3060.000000
# std        26097.908979      12090.216824           1.517382      6241.434948
# min         5000.000000       2000.000000           1.000000         0.000000
# 25%        23550.000000      10000.000000           3.000000         0.000000
# 50%        35000.000000      15500.000000           4.000000         0.000000
# 75%        50375.000000      25000.000000           5.000000      3500.000000
# max       100000.000000      50000.000000           7.000000     35000.000000
#
# ...

# %%
df.dtypes
# Out:
# Mthly_HH_Income              int64
# Mthly_HH_Expense             int64
# No_of_Fly_Members            int64
# Emi_or_Rent_Amt              int64
# Annual_HH_Income             int64
# Highest_Qualified_Member    object
# No_of_Earning_Members        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Mthly_HH_Income           50 non-null     int64
#  1   Mthly_HH_Expense          50 non-null     int64
#  2   No_of_Fly_Members         50 non-null     int64
#  3   Emi_or_Rent_Amt           50 non-null     int64
#  4   Annual_HH_Income          50 non-null     int64
#  5   Highest_Qualified_Member  50 non-null     object
#  6   No_of_Earning_Members     50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
df.isnull().sum()
# Out:
# Mthly_HH_Income             0
# Mthly_HH_Expense            0
# No_of_Fly_Members           0
# Emi_or_Rent_Amt             0
# Annual_HH_Income            0
# Highest_Qualified_Member    0
# No_of_Earning_Members       0
# dtype: int64

# %%
df.shape
# Out:
# (50, 7)

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# **4.What is the Mean Expense of a Household?**

# %%
df["Mthly_HH_Expense"].mean()
# Out:
# 18818.0

# %% [markdown]
# **5.What is the Median Household Expense?**

# %%
df["Mthly_HH_Expense"].median()
# Out:
# 15500.0

# %% [markdown]
# **6.What is the Monthly Expense for most of the Households?**

# %%
df["Mthly_HH_Expense"].mode()
# Out:
# 0    25000
# Name: Mthly_HH_Expense, dtype: int64

# %% [markdown]
# **7.Plot the Histogram to count the Highest qualified member**

# %%
df["Highest_Qualified_Member"].value_counts()
# Out:
# Graduate          19
# Under-Graduate    10
# Professional      10
# Post-Graduate      6
# Illiterate         5
# Name: Highest_Qualified_Member, dtype: int64

# %%
sns.countplot(x="Highest_Qualified_Member", data=df)
plt.xlabel("Highest_Qualified_Member",c="Brown")
plt.show()

# %% [markdown]
# **8.Calculate IQR(difference between 75% and 25% quartile)**

# %%
## IQR for Mthly_HH_Income only
df.describe(include="all")
# Out:
#         Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# count         50.000000         50.000000          50.000000        50.000000
# unique              NaN               NaN                NaN              NaN
# top                 NaN               NaN                NaN              NaN
# freq                NaN               NaN                NaN              NaN
# mean       41558.000000      18818.000000           4.060000      3060.000000
# std        26097.908979      12090.216824           1.517382      6241.434948
# min         5000.000000       2000.000000           1.000000         0.000000
# 25%        23550.000000      10000.000000           3.000000         0.000000
# 50%        35000.000000      15500.000000           4.000000         0.000000
# 75%        50375.000000      25000.000000           5.000000      3500.000000
# max       100000.000000      50000.000000           7.000000     35000.000000
#
# ...

# %%
q3=50375
q1=23550
iqr=q3-q1
iqr
# Out:
# 26825

# %%
## IQR for all the provided columns.
quartiles=df.quantile(q=[0.25, 0.75], axis=0, numeric_only=True)
IQR_for_all_numeric_columns=quartiles.loc[0.75]-quartiles.loc[0.25]
IQR=pd.DataFrame(IQR_for_all_numeric_columns,columns=['IQR'])
IQR
# Out:
#                             IQR
# Mthly_HH_Income         26825.0
# Mthly_HH_Expense        15000.0
# No_of_Fly_Members           2.0
# Emi_or_Rent_Amt          3500.0
# Annual_HH_Income       335970.0
# No_of_Earning_Members       1.0

# %% [markdown]
# **9.Calculate Standard Deviation for first 4 columns.**

# %%
df[['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members', 'Emi_or_Rent_Amt']].std()
# Out:
# Mthly_HH_Income      26097.908979
# Mthly_HH_Expense     12090.216824
# No_of_Fly_Members        1.517382
# Emi_or_Rent_Amt       6241.434948
# dtype: float64

# %% [markdown]
# **10.Calculate Variance for first 3 columns**

# %%
df[['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members']].var()
# Out:
# Mthly_HH_Income      6.811009e+08
# Mthly_HH_Expense     1.461733e+08
# No_of_Fly_Members    2.302449e+00
# dtype: float64

# %% [markdown]
# **11.Calculate the count of Highest qualified member.**

# %%
df["Highest_Qualified_Member"].value_counts()
# Out:
# Graduate          19
# Under-Graduate    10
# Professional      10
# Post-Graduate      6
# Illiterate         5
# Name: Highest_Qualified_Member, dtype: int64

# %%
df.Highest_Qualified_Member.value_counts().head(1)
# Out:
# Graduate    19
# Name: Highest_Qualified_Member, dtype: int64

# %% [markdown]
# **12.Plot the Histogram to count the No_of_Earning_Members**

# %%
sns.countplot(x="No_of_Earning_Members", data=df, palette="Set1")
plt.xlabel("No_of_Earning_Members",color="Brown")
plt.show()

# %%
df. No_of_Earning_Members.value_counts()
# Out:
# 1    33
# 2    12
# 3     4
# 4     1
# Name: No_of_Earning_Members, dtype: int64

# %% [markdown]
# **13.Suppose you have option to invest in Stock A or Stock B. The stocks • have different expected returns and standard deviations. The expected return of Stock A is 15% and Stock B is 10%. Standard Deviation of the returns of these stocks is 10% and 5% respectively**

# %% [markdown]
# As mentioned the return and standard deviation on stock A is 15% and 10%. likewise return and standard deviation o stcok B are 10% and 5%. To make better comparison between the 2 lets keep risk as 3% in both cases. Accordingly after calculating sharpe ratio, stock A gives 1.2% return and stock B gives 1.4 return.
#
# So it is wise to select stock B. However, it's essential to consider your risk tolerance and investment objectives while making a decision.
